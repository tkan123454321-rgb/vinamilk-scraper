# %%
import requests


r = requests.get("https://example.com/api",timeout=10)
       # mã lỗi
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[137], line 4
#       1 import requests
# ----> 4 r = requests.get("https://example.com/api",timeout=10)
#       5        # mã lỗi
#
# File ~/Documents/suici_mouse_scraper/my_python_env/lib/python3.13/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/Documents/suici_mouse_scraper/my_python_env/lib/python3.13/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
# ...
